# %% [markdown]
# <a href="https://colab.research.google.com/github/manish23454/Image_processing/blob/manish/IPPR_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2;
image = cv2.imread('/choice-variation-concept.webp');
from google.colab.patches import cv2_imshow;
cv2_imshow(image);
print('origianl image');
# Out:
# <PIL.Image.Image image mode=RGB size=612x344>
# sigiral image

# %%
# !pwd
# Out:
# /content

# %%
image1 = cv2.imread('/choice-variation-concept.webp',0)
cv2_imshow(image1)
print('image1')
# Out:
# <PIL.Image.Image image mode=L size=612x344>
# image1

# %%
#convert an image to number of arrat
import cv2;
image  = cv2.imread('/choice-variation-concept.webp');
from google.colab.patches import cv2_imshow;
cv2_imshow(image)
from numpy import asarray;
data = asarray(image);
print(data.shape);
print(data)
# Out:
# <PIL.Image.Image image mode=RGB size=612x344>
# (344, 612, 3)
# [[[156 156 156]
#   [156 156 156]
#   [157 157 157]
#   ...
#   [121 122 120]
#   [119 121 121]
#   [119 121 121]]
#
#  [[156 156 156]
#   [156 156 156]
#   [157 157 157]
#   ...
#   [121 122 120]
#   [121 122 120]
#   [121 121 121]]
#
#  [[157 157 157]
#   [157 157 157]
#   [158 158 158]
#   ...
#   [123 122 118]
#   [123 122 118]
#   [123 122 120]]
#
#  ...
#
#  [[ 15  23  12]
#   [ 15  23  12]
#   [ 15  23  12]
#   ...
#   [  2  27  21]
#   [  0  21  15]
#   [  0  17  11]]
#
#  [[ 16  24  13]
#   [ 16  24  13]
#   [ 16  24  13]
#   ...
#   [  6  32  28]
#   [  2  26  22]
#   [  0  23  19]]
#
#  [[ 16  24  13]
#   [ 16  24  13]
#   [ 16  24  13]
#   ...
#   [ 14  43  38]
#   [  9  36  31]
#   [  7  31  27]]]

# %%
#image rotation
import imutils
image = cv2.imread('/choice-variation-concept.webp');
cv2_imshow(image);
rotated = imutils.rotate(image,180);
cv2_imshow(rotated);
